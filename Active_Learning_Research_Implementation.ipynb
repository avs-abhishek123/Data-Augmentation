# %% [markdown]
# Active learning - subset of ML
#
# Suppose I have a disease and I dont know what type of disease it is. SO, I go to doctor & dont speak to him. Then it becomes difficult for the doctor to understand what is my disease.
#
# So, what he will do is, he will ask certain types of questions like - some pain in this area or some irritation etc
#
# So,  he is asking a query
#
#
# ---
#
#
# ### Active learning is also called as query learning where we ask relevant queries to extract that particular information.
#
#
# ---
#
#
# ###Active learning is also called as Optimal Experimental design
#
#
# ---
#
#
# It is focused on region of interest.
#
# ROI - region of interest

# %% [markdown]
# There are three scenarios for AL:
# 1. Membership query synthesis, i.e., a generated sample is sent to an oracle for labeling.
# 2. Stream-Based selective sampling, i.e, each sample is considered separately -in our case for label-querying or rejection. Similarly to online-learning, the data is not saved, there are no assumptions on data distribution, and therefore it is adaptive to change.
# 3. Pool-Based sampling, i.e., sampled are chosen from a pool of unlabeled data for the purpose of labeling [3].
# In this tutorial we use the third scenario.

# %% [markdown]
# The following pseudo algorithm represents the learning process, as written in the code, for pool-based sampling:
# 1. Divide the data to a ‘pool’ and a test-set
# 2. Select ‘k’ samples from the pool for the initial train-set and label them, the remaining data will be the validation-set
# 3. Normalize all the sets
# 4. Train the Model using the train-set, with balanced weights.
# 5. Use the trained model with the validation-set, get probabilities per sample.
# 6. Use the trained model with the test-set, get performance measures.
# 7. Select ‘k’ most-informative samples based on per-sample-probabilities, i.e., those that the model was most uncertain about regarding their labelling.
# 8. Move these ‘k’ samples from the validation set to the train-set and query their labels.
# 9. Inverse normalization for all the data-sets
# 10. Stop according to the stop criterion, otherwise go to 3.

# %% [markdown]
# # **KEY HYPOTHESIS IN ACTIVE LEARNING**
#
# ## **The learning algorithm has the liberty to choose the data to learn from.**
#
# In other tye of learning, in supervised and unsupervised learning what we did is, we had a large dataset and we just randomly assigned different instances and data, in order to make the data learning algorithm to learn. It is like a brute force approach, where we didn't had a particular path to inorder to estimate the model & so it take some time to detect what actually the model is going to learn
#
# It is a shortcut to this, where we impose certain kind of queries to extract the relevant information
#
# 2 types of data -
# 1. unlabeled data [ Easy to get ]
# 2. labelled data [ Hard to get ]

# %% [markdown]
# In medical applications, suppose I have different types of diseases, under different taxanomies. so in labelled data it becomes easier for us to categorize the disease so it becomes easier to classify
#
# but if other person comes with a disease with a completely different characteristics from the list or template that we had,  so here we need to have active learning or query based learning
#
# So, there we need to have active or query based learning, so we re extracting that relevant info which were not there earlier, that would refine or leverage, existing training set.
#
# then we construct a model to learn new disease or whatever kind of info it is.

# %% [markdown]
# ##PAPERS
#
# https://paperswithcode.com/paper/alipy-active-learning-in-python
#
# https://www.researchgate.net/publication/230895538_Scalable_Active_Learning_for_Multiclass_Image_Classification/figures?lo=1
#
# https://github.com/micka-charpak/ProjetAnalyse
#
# https://towardsdatascience.com/active-learning-tutorial-57c3398e34d
#
# https://towardsdatascience.com/entropy-is-a-measure-of-uncertainty-e2c000301c2c
#
#
# To read
#
# https://www.researchgate.net/publication/350774010_Application_of_active_learning_algorithm_in_handwriting_recognition_numbers

# %% [markdown]
# # **Active learning block diagram**

# %% [markdown]
# https://www.researchgate.net/publication/230895538_Scalable_Active_Learning_for_Multiclass_Image_Classification/figures?lo=1

# %% [markdown]
# ![Block-schematic-of-the-active-learning-setting-Our-focus-in-this-paper-is-on-the-query.png](data:image/png;base64,...)

# %% [markdown]
# https://towardsdatascience.com/introduction-to-active-learning-117e0740d7cc

# %% [markdown]
# Active learning is a machine learning framework in which the learning algorithm can interactively query a user (teacher or oracle) to label new data points with the true labels. The process of active learning is also referred to as optimal experimental design.
#
# The motivation for active learning is a scenario in which we have a large pool of unlabelled data. Consider the problem of training an image classification model to distinguish between cats and dogs. There are millions of images out there of each, but not all of them are needed to train a good model. Some images may offer more clarity and information than others. Another similar application is classifying the content of Youtube videos, where the data is inherently dense and there exists a lot of it.
#
# Passive learning, the standard framework in which a large quantity of labelled data is passed to the algorithm, requires significant effort in labelling the entire set of data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **The algorithm iteratively selects the most informative examples based on some value metric and sends those unlabelled examples to a labelling oracle, who returns the true labels for those queried examples back to the algorithm.**

# %% [markdown]
# # **POOL BASED ACTIVE LEARNING**

# %% [markdown]
# suppose we have a waste land, and different type of waste is dumbed there.
#
# and the person labels it like X1,X2,X3....
#
# This can only be done by human being, that person is called as
# # **ORACLE**
#
# he will pick up the data from U (Unlabelled pool)
#
# he will query this and update it to labelled instanes.
#
#
# .  >>>>>Training set(L)----------*learn model*----------> ML Algorithm ----------> Unlabelled pool(U) --------*select query*--------> ORACLE (person)>>> Training set
#
# in each iteration when we get a training set, then we will leverage the training set by refining it
#
# Training set<<<<< Unalabelled pool

# %% [markdown]
# # **EVALUATION OF PERFORMANCE METRICS OF ACTIVE LEARNING**

# %% [markdown]
# We do one type of sampling technique called uncertainity based sampling.
#
# like random sampling, boot strapping, cross validation but the above is used
#
# As, uncertainity based sampling performs much better compared to other sampling techniques. here, active learning comes.

# %% [markdown]
# # **In several cases, active learning performs better than random sampling.**

# %% [markdown]
# Active learning is motivated by the understanding that not all labelled examples are equally important. With uniform random sampling over all of the examples, the learned model doesn’t quite represent the division between classes. However, active learning selects examples near the class boundary, and is able to find a more representative classifier

# %% [markdown]
# #In active learning, the most informative data points are generally the ones that the model is most uncertain about. This necessitates various metrics to quantify and compare uncertainty of examples. ??????
#
# https://towardsdatascience.com/introduction-to-active-learning-117e0740d7cc

# %% [markdown]
# # **Different Active Learning Frameworks**

# %% [markdown]
# Active learning is considered to be a semi-supervised learning method, between unsupervised being using 0% of the learning examples and fully supervised being using 100% of the examples.
#
# By iteratively increasing the size of our labelled training set, we can achieve
# 1. greater performance, near fully-supervised performance,
# 2. with a fraction of the cost or time to train using all of the data.

# %% [markdown]
# # **A. Pool-based Active Learning**
#
# In pool-based sampling, training examples are chosen from a large pool of unlabelled data. Selected training examples from this pool are labelled by the oracle.

# %% [markdown]
# # **B. Stream-based Active Learning**
#
# In stream-based active learning, the set of all training examples is presented to the algorithm as a stream. Each example is sent individually to the algorithm for consideration. The algorithm must make an immediate decision on whether to label or not label this example. Selected training examples from this pool are labelled by the oracle, and the label is immediately received by the algorithm before the next example is shown for consideration.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **Uncertainty Measures**
#
# The decision for selecting the most informative data points is dependent on the uncertainty measure used in selection.
#
# In pool-based sampling, the active learning algorithm selects examples to add to the growing training set that are the most informative.

# %% [markdown]
# # **The most informative(from which we get lot of info) examples are the ones that the classifier is the least certain about**

# %% [markdown]
# The intuition here is that the examples for which the model has the least certainty will likely be the most difficult examples — specifically the examples that lie near the class boundaries. The learning algorithm will gain the most information about the class boundaries by observing the difficult examples.

# %% [markdown]
# # **Below are four common uncertainty measures used in active learning to select the most informative examples.**

# %% [markdown]
# # **1. Smallest Margin Uncertainty**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The smallest margin uncertainty is a best-versus-second-best uncertainty comparison. The smallest margin uncertainty (SMU) is the classification probability of the most likely class minus the classification probability of the second most likely class
#
# The intuition behind this metric is that if the probability of the most likely class is significantly greater than the probability of the second most likely class, then the classifier is more certain about the example’s class membership.
#
# Likewise, if the probability of the most likely class is not much greater than the probability of the second most likely class, then the classifier is less certain about the example’s class membership. The active learning algorithm will select the example with the minimum SMU value.

# %% [markdown]
# # **2. Least Confidence Uncertainty**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Least confidence uncertainty (LCU) is selecting the example for which the classifier is least certain about the selected class.
#
# LCU selection only looks at the most likely class, and selects the example that has the lowest probability assigned to that class.

# %% [markdown]
# # **3. Entropy Reduction**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entropy is the measure of the uncertainty of a random variable. In this experiment, we use **Shannon Entropy**.
#
# Shannon entropy has several basic properties,
# including
# (1) uniform distributions have maximum uncertainty,
#
# (2) uncertainty is additive for independent events, and
#
# (3) adding an outcome with zero probability has no effect, and
#
# (4) events with a certain outcome have zero effect

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# Considering class predictions as outcomes, we can measure Shannon entropy of the predicted class probabilities.

# %% [markdown]
# Higher values of entropy indicate greater uncertainty in the probability distribution
#
#  In each active learning step, for every unlabelled example in the training set, the active learning algorithm computes the entropy over the predicted class probabilities, and selects the example with the highest entropy.
#
# ## **The example with the highest entropy is the example for which the classifier is least certain about its class membership.**

# %% [markdown]
# # **4. Largest Margin Uncertainty**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The largest margin uncertainty is a best-versus-worst uncertainty comparison
#
# The largest margin uncertainty (LMU) is the classification probability of the most likely class minus the classification probability of the least likely class.
#
# ### **The intuition behind this metric is that if the probability of the most likely class is significantly greater than the probability of the least likely class, then the classifier is more certain about the example’s class membership**
#
#  Likewise, if the probability of the most likely class is not much greater than the probability of the least likely class, then the classifier is less certain about the example’s class membership. The active learning algorithm will select the example with the minimum LMU value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A principle bottleneck in large-scale classification tasks is the large number of training examples needed for training a classifier. Using active learning, we can reduce the number of training examples needed to teach a classifier by strategically selecting particular examples.
